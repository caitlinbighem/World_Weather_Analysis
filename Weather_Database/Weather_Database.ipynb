# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 755

# %%
#Import dependencies
import requests
from config import weather_api_key
import time

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if i % 50 == 0 and i >= 50:
        set_count += 1
        record_count = 1
        #time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    
    # If an error occurs, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | north bend
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | ivangorod
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | maumere
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | norman wells
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | nouakchott
# Processing Record 16 of Set 1 | turukhansk
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | hambantota
# Processing Record 21 of Set 1 | luderitz
# Processing Record 22 of Set 1 | plettenberg bay
# Processing Record 23 of Set 1 | hobyo
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | dikson
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | krasnovka
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 1 | ust-kan
# Processing Record 35 of Set 1 | sur
# Processing Record 36 of Set 1 | bom despacho
# Processing Record 37 of Set 1 | kaeo
# Processing Record 38 of Set 1 | straumen
# Processing Record 39 of Set 1 | namibe
# Processing Record 40 of Set 1 | priiskovyy
# Processing Record 41 of Set 1 | vorozhba
# Processing Record 42 of Set 1 | pisco
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | ponta do sol
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | kaitangata
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | beloha
# Processing Record 49 of Set 1 | lata
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | xuanzhou
# Processing Record 2 of Set 2 | shieli
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | kruisfontein
# Processing Record 6 of Set 2 | manzanillo
# Processing Record 7 of Set 2 | bereda
# Processing Record 8 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 2 | sydney
# Processing Record 10 of Set 2 | ayan
# Processing Record 11 of Set 2 | netivot
# Processing Record 12 of Set 2 | tual
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | basco
# Processing Record 15 of Set 2 | dryden
# Processing Record 16 of Set 2 | quatre cocos
# Processing Record 17 of Set 2 | pimentel
# Processing Record 18 of Set 2 | ushuaia
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | abu samrah
# Processing Record 22 of Set 2 | samfya
# Processing Record 23 of Set 2 | egvekinot
# Processing Record 24 of Set 2 | naryan-mar
# Processing Record 25 of Set 2 | port augusta
# Processing Record 26 of Set 2 | yunhe
# Processing Record 27 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 2 | nhulunbuy
# Processing Record 29 of Set 2 | mayo
# Processing Record 30 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 2 | griffith
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | mantua
# Processing Record 34 of Set 2 | ndele
# Processing Record 35 of Set 2 | tugulym
# Processing Record 36 of Set 2 | cairns
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | druzhba
# Processing Record 40 of Set 2 | faanui
# Processing Record 41 of Set 2 | oktyabrskoye
# Processing Record 42 of Set 2 | atambua
# Processing Record 43 of Set 2 | tazovskiy
# Processing Record 44 of Set 2 | nuuk
# Processing Record 45 of Set 2 | adelanto
# Processing Record 46 of Set 2 | geraldton
# Processing Record 47 of Set 2 | hobart
# Processing Record 48 of Set 2 | mehamn
# Processing Record 49 of Set 2 | macaboboni
# City not found. Skipping...
# Processing Record 50 of Set 2 | puerto ayora
# Processing Record 1 of Set 3 | camopi
# Processing Record 2 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | torbay
# Processing Record 5 of Set 3 | atar
# Processing Record 6 of Set 3 | bubaque
# Processing Record 7 of Set 3 | port hardy
# Processing Record 8 of Set 3 | aasiaat
# Processing Record 9 of Set 3 | makubetsu
# Processing Record 10 of Set 3 | souillac
# Processing Record 11 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | santa marta
# Processing Record 14 of Set 3 | woodward
# Processing Record 15 of Set 3 | pundaguitan
# Processing Record 16 of Set 3 | grand gaube
# Processing Record 17 of Set 3 | busselton
# Processing Record 18 of Set 3 | solnechnyy
# Processing Record 19 of Set 3 | scarborough
# Processing Record 20 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 3 | sioux falls
# Processing Record 22 of Set 3 | coihaique
# Processing Record 23 of Set 3 | acapulco
# Processing Record 24 of Set 3 | beringovskiy
# Processing Record 25 of Set 3 | marrakesh
# Processing Record 26 of Set 3 | mandalgovi
# Processing Record 27 of Set 3 | lavumisa
# Processing Record 28 of Set 3 | lasa
# Processing Record 29 of Set 3 | tecolutilla
# Processing Record 30 of Set 3 | sitka
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | dunedin
# Processing Record 33 of Set 3 | saldanha
# Processing Record 34 of Set 3 | esperance
# Processing Record 35 of Set 3 | rio grande
# Processing Record 36 of Set 3 | kununurra
# Processing Record 37 of Set 3 | loandjili
# Processing Record 38 of Set 3 | buchanan
# Processing Record 39 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | taicheng
# Processing Record 42 of Set 3 | igarka
# Processing Record 43 of Set 3 | labuhan
# Processing Record 44 of Set 3 | sidney
# Processing Record 45 of Set 3 | belmonte
# Processing Record 46 of Set 3 | bara
# Processing Record 47 of Set 3 | muroto
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | chivacoa
# Processing Record 50 of Set 3 | vaini
# Processing Record 1 of Set 4 | kavadarci
# Processing Record 2 of Set 4 | great falls
# Processing Record 3 of Set 4 | bonito
# Processing Record 4 of Set 4 | lengshuijiang
# Processing Record 5 of Set 4 | poum
# Processing Record 6 of Set 4 | nome
# Processing Record 7 of Set 4 | cayenne
# Processing Record 8 of Set 4 | bandarbeyla
# Processing Record 9 of Set 4 | tiksi
# Processing Record 10 of Set 4 | old shinyanga
# Processing Record 11 of Set 4 | ostrovnoy
# Processing Record 12 of Set 4 | sorland
# Processing Record 13 of Set 4 | kasempa
# Processing Record 14 of Set 4 | yulara
# Processing Record 15 of Set 4 | pocone
# Processing Record 16 of Set 4 | chuy
# Processing Record 17 of Set 4 | lehi
# Processing Record 18 of Set 4 | saint anthony
# Processing Record 19 of Set 4 | trairi
# Processing Record 20 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 4 | san vicente
# Processing Record 22 of Set 4 | cherskiy
# Processing Record 23 of Set 4 | borama
# City not found. Skipping...
# Processing Record 24 of Set 4 | arlit
# Processing Record 25 of Set 4 | lorengau
# Processing Record 26 of Set 4 | tamna
# Processing Record 27 of Set 4 | huarmey
# Processing Record 28 of Set 4 | berlevag
# Processing Record 29 of Set 4 | maniitsoq
# Processing Record 30 of Set 4 | ordu
# Processing Record 31 of Set 4 | barra dos coqueiros
# Processing Record 32 of Set 4 | luganville
# Processing Record 33 of Set 4 | klaksvik
# Processing Record 34 of Set 4 | bambous virieux
# Processing Record 35 of Set 4 | badou
# Processing Record 36 of Set 4 | kapit
# Processing Record 37 of Set 4 | san cristobal
# Processing Record 38 of Set 4 | lompoc
# Processing Record 39 of Set 4 | asau
# Processing Record 40 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 4 | kavieng
# Processing Record 42 of Set 4 | vostok
# Processing Record 43 of Set 4 | antofagasta
# Processing Record 44 of Set 4 | vila
# Processing Record 45 of Set 4 | ahipara
# Processing Record 46 of Set 4 | christchurch
# Processing Record 47 of Set 4 | gikongoro
# Processing Record 48 of Set 4 | chokurdakh
# Processing Record 49 of Set 4 | hithadhoo
# Processing Record 50 of Set 4 | atuona
# Processing Record 1 of Set 5 | estelle
# Processing Record 2 of Set 5 | bukachacha
# Processing Record 3 of Set 5 | provideniya
# Processing Record 4 of Set 5 | iskateley
# Processing Record 5 of Set 5 | tessalit
# Processing Record 6 of Set 5 | vila velha
# Processing Record 7 of Set 5 | katsuura
# Processing Record 8 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 5 | mahebourg
# Processing Record 10 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 5 | zalantun
# Processing Record 12 of Set 5 | friedrichshafen
# Processing Record 13 of Set 5 | nishihara
# Processing Record 14 of Set 5 | abnub
# Processing Record 15 of Set 5 | tabuk
# Processing Record 16 of Set 5 | husavik
# Processing Record 17 of Set 5 | magole
# Processing Record 18 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 19 of Set 5 | tarakan
# Processing Record 20 of Set 5 | inhambane
# Processing Record 21 of Set 5 | nyuksenitsa
# Processing Record 22 of Set 5 | quijingue
# Processing Record 23 of Set 5 | since
# Processing Record 24 of Set 5 | villa literno
# Processing Record 25 of Set 5 | sobolevo
# Processing Record 26 of Set 5 | mudyuga
# City not found. Skipping...
# Processing Record 27 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 28 of Set 5 | piritiba
# Processing Record 29 of Set 5 | hamilton
# Processing Record 30 of Set 5 | linares
# Processing Record 31 of Set 5 | umm lajj
# Processing Record 32 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 5 | ferme-neuve
# Processing Record 34 of Set 5 | ilulissat
# Processing Record 35 of Set 5 | bilma
# Processing Record 36 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 37 of Set 5 | kamina
# Processing Record 38 of Set 5 | kavaratti
# Processing Record 39 of Set 5 | tolmezzo
# Processing Record 40 of Set 5 | henties bay
# Processing Record 41 of Set 5 | altonia
# City not found. Skipping...
# Processing Record 42 of Set 5 | kano
# Processing Record 43 of Set 5 | matagami
# Processing Record 44 of Set 5 | muros
# Processing Record 45 of Set 5 | kysyl-syr
# Processing Record 46 of Set 5 | kyra
# Processing Record 47 of Set 5 | ladario
# Processing Record 48 of Set 5 | ponta delgada
# Processing Record 49 of Set 5 | indiaroba
# Processing Record 50 of Set 5 | ramat yishay
# Processing Record 1 of Set 6 | thompson
# Processing Record 2 of Set 6 | port elizabeth
# Processing Record 3 of Set 6 | campo maior
# Processing Record 4 of Set 6 | beberibe
# Processing Record 5 of Set 6 | fortuna
# Processing Record 6 of Set 6 | portland
# Processing Record 7 of Set 6 | oranjestad
# Processing Record 8 of Set 6 | abong mbang
# Processing Record 9 of Set 6 | amurzet
# Processing Record 10 of Set 6 | goderich
# Processing Record 11 of Set 6 | soyo
# Processing Record 12 of Set 6 | darhan
# Processing Record 13 of Set 6 | oranjemund
# Processing Record 14 of Set 6 | rosarito
# Processing Record 15 of Set 6 | nanortalik
# Processing Record 16 of Set 6 | kota kinabalu
# Processing Record 17 of Set 6 | ola
# Processing Record 18 of Set 6 | kosugi
# Processing Record 19 of Set 6 | aragarcas
# Processing Record 20 of Set 6 | suicheng
# Processing Record 21 of Set 6 | makat
# Processing Record 22 of Set 6 | khani
# Processing Record 23 of Set 6 | alofi
# Processing Record 24 of Set 6 | kars
# Processing Record 25 of Set 6 | zhezkazgan
# Processing Record 26 of Set 6 | beidao
# Processing Record 27 of Set 6 | dudinka
# Processing Record 28 of Set 6 | vikersund
# Processing Record 29 of Set 6 | vidalia
# Processing Record 30 of Set 6 | puyang
# Processing Record 31 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 6 | rio gallegos
# Processing Record 33 of Set 6 | te anau
# Processing Record 34 of Set 6 | brodick
# Processing Record 35 of Set 6 | salalah
# Processing Record 36 of Set 6 | kijang
# Processing Record 37 of Set 6 | necochea
# Processing Record 38 of Set 6 | victoria
# Processing Record 39 of Set 6 | harstad
# Processing Record 40 of Set 6 | tara
# Processing Record 41 of Set 6 | sao joao da barra
# Processing Record 42 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 6 | binzhou
# Processing Record 44 of Set 6 | paragominas
# Processing Record 45 of Set 6 | pedro juan caballero
# Processing Record 46 of Set 6 | port hedland
# Processing Record 47 of Set 6 | mount gambier
# Processing Record 48 of Set 6 | urucara
# Processing Record 49 of Set 6 | flinders
# Processing Record 50 of Set 6 | kodiak
# Processing Record 1 of Set 7 | mount isa
# Processing Record 2 of Set 7 | faya
# Processing Record 3 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 7 | los llanos de aridane
# Processing Record 5 of Set 7 | vao
# Processing Record 6 of Set 7 | thinadhoo
# Processing Record 7 of Set 7 | san patricio
# Processing Record 8 of Set 7 | kaduqli
# Processing Record 9 of Set 7 | yangjiang
# Processing Record 10 of Set 7 | kedrovyy
# Processing Record 11 of Set 7 | safford
# Processing Record 12 of Set 7 | porlamar
# Processing Record 13 of Set 7 | abonnema
# Processing Record 14 of Set 7 | puerto narino
# Processing Record 15 of Set 7 | puerto suarez
# Processing Record 16 of Set 7 | charters towers
# Processing Record 17 of Set 7 | georgetown
# Processing Record 18 of Set 7 | puro
# Processing Record 19 of Set 7 | zhigansk
# Processing Record 20 of Set 7 | sao filipe
# Processing Record 21 of Set 7 | tigil
# Processing Record 22 of Set 7 | arraial do cabo
# Processing Record 23 of Set 7 | codrington
# Processing Record 24 of Set 7 | kabanjahe
# Processing Record 25 of Set 7 | javornik
# Processing Record 26 of Set 7 | hami
# Processing Record 27 of Set 7 | mao
# Processing Record 28 of Set 7 | wanning
# Processing Record 29 of Set 7 | sidi ali
# Processing Record 30 of Set 7 | camacha
# Processing Record 31 of Set 7 | bathsheba
# Processing Record 32 of Set 7 | caravelas
# Processing Record 33 of Set 7 | nelson bay
# Processing Record 34 of Set 7 | hukuntsi
# Processing Record 35 of Set 7 | juneau
# Processing Record 36 of Set 7 | kloulklubed
# Processing Record 37 of Set 7 | umba
# Processing Record 38 of Set 7 | longyearbyen
# Processing Record 39 of Set 7 | elko
# Processing Record 40 of Set 7 | murphy
# Processing Record 41 of Set 7 | cockburn town
# Processing Record 42 of Set 7 | lagoa
# Processing Record 43 of Set 7 | tromso
# Processing Record 44 of Set 7 | varhaug
# Processing Record 45 of Set 7 | broome
# Processing Record 46 of Set 7 | betki
# City not found. Skipping...
# Processing Record 47 of Set 7 | luquillo
# Processing Record 48 of Set 7 | alice springs
# Processing Record 49 of Set 7 | duz
# City not found. Skipping...
# Processing Record 50 of Set 7 | galle
# Processing Record 1 of Set 8 | belmopan
# Processing Record 2 of Set 8 | churapcha
# Processing Record 3 of Set 8 | machilipatnam
# Processing Record 4 of Set 8 | severo-kurilsk
# Processing Record 5 of Set 8 | herouville-saint-clair
# Processing Record 6 of Set 8 | jardim
# Processing Record 7 of Set 8 | arman
# Processing Record 8 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 9 of Set 8 | susanville
# Processing Record 10 of Set 8 | tuatapere
# Processing Record 11 of Set 8 | agadez
# Processing Record 12 of Set 8 | filadelfia
# Processing Record 13 of Set 8 | vila franca do campo
# Processing Record 14 of Set 8 | meulaboh
# Processing Record 15 of Set 8 | saint-philippe
# Processing Record 16 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 8 | marathon
# Processing Record 18 of Set 8 | zamora
# Processing Record 19 of Set 8 | gizo
# Processing Record 20 of Set 8 | san luis
# Processing Record 21 of Set 8 | taonan
# Processing Record 22 of Set 8 | lisakovsk
# Processing Record 23 of Set 8 | clyde river
# Processing Record 24 of Set 8 | kendari
# Processing Record 25 of Set 8 | sint-lievens-houtem
# Processing Record 26 of Set 8 | wad madani
# Processing Record 27 of Set 8 | pemberton
# Processing Record 28 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 8 | vanimo
# Processing Record 30 of Set 8 | alta floresta
# Processing Record 31 of Set 8 | nakamura
# Processing Record 32 of Set 8 | clermont
# Processing Record 33 of Set 8 | sao jose de ribamar
# Processing Record 34 of Set 8 | mizunami
# Processing Record 35 of Set 8 | sisimiut
# Processing Record 36 of Set 8 | hay river
# Processing Record 37 of Set 8 | san-pedro
# Processing Record 38 of Set 8 | guerrero negro
# Processing Record 39 of Set 8 | victor harbor
# Processing Record 40 of Set 8 | waddan
# Processing Record 41 of Set 8 | nemuro
# Processing Record 42 of Set 8 | chemal
# Processing Record 43 of Set 8 | garden city
# Processing Record 44 of Set 8 | ulaanbaatar
# Processing Record 45 of Set 8 | jaguaribe
# Processing Record 46 of Set 8 | narsaq
# Processing Record 47 of Set 8 | posse
# Processing Record 48 of Set 8 | bilibino
# Processing Record 49 of Set 8 | contepec
# Processing Record 50 of Set 8 | saint combs
# City not found. Skipping...
# Processing Record 1 of Set 9 | priargunsk
# Processing Record 2 of Set 9 | hasaki
# Processing Record 3 of Set 9 | wasilla
# Processing Record 4 of Set 9 | aklavik
# Processing Record 5 of Set 9 | nynashamn
# Processing Record 6 of Set 9 | lavrentiya
# Processing Record 7 of Set 9 | saint george
# Processing Record 8 of Set 9 | richards bay
# Processing Record 9 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 10 of Set 9 | martapura
# Processing Record 11 of Set 9 | kundiawa
# Processing Record 12 of Set 9 | ariquemes
# Processing Record 13 of Set 9 | brokopondo
# Processing Record 14 of Set 9 | kiunga
# Processing Record 15 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 16 of Set 9 | kushima
# Processing Record 17 of Set 9 | ancud
# Processing Record 18 of Set 9 | jarjis
# City not found. Skipping...
# Processing Record 19 of Set 9 | araouane
# Processing Record 20 of Set 9 | abu dhabi
# Processing Record 21 of Set 9 | lazaro cardenas
# Processing Record 22 of Set 9 | kanigoro
# Processing Record 23 of Set 9 | rockland
# Processing Record 24 of Set 9 | guymon
# Processing Record 25 of Set 9 | honningsvag
# Processing Record 26 of Set 9 | tevaitoa
# Processing Record 27 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 9 | nouadhibou
# Processing Record 29 of Set 9 | jalu
# Processing Record 30 of Set 9 | carros
# Processing Record 31 of Set 9 | spearfish
# Processing Record 32 of Set 9 | muravlenko
# Processing Record 33 of Set 9 | katha
# City not found. Skipping...
# Processing Record 34 of Set 9 | jermuk
# Processing Record 35 of Set 9 | colmar
# Processing Record 36 of Set 9 | camana
# Processing Record 37 of Set 9 | la asuncion
# Processing Record 38 of Set 9 | lucapa
# Processing Record 39 of Set 9 | isangel
# Processing Record 40 of Set 9 | soe
# Processing Record 41 of Set 9 | gunjur
# Processing Record 42 of Set 9 | herat
# Processing Record 43 of Set 9 | chifeng
# Processing Record 44 of Set 9 | maarianhamina
# Processing Record 45 of Set 9 | zabol
# Processing Record 46 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 9 | pitea
# Processing Record 48 of Set 9 | san ramon de la nueva oran
# Processing Record 49 of Set 9 | suclayin
# Processing Record 50 of Set 9 | aberystwyth
# Processing Record 1 of Set 10 | strezhevoy
# Processing Record 2 of Set 10 | chernigovka
# Processing Record 3 of Set 10 | palu
# Processing Record 4 of Set 10 | bhabua
# Processing Record 5 of Set 10 | airai
# Processing Record 6 of Set 10 | parksepa
# Processing Record 7 of Set 10 | bardiyah
# Processing Record 8 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 10 | shaoguan
# Processing Record 10 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 11 of Set 10 | bac lieu
# Processing Record 12 of Set 10 | asfi
# Processing Record 13 of Set 10 | westport
# Processing Record 14 of Set 10 | padang
# Processing Record 15 of Set 10 | karwar
# Processing Record 16 of Set 10 | rudbar
# Processing Record 17 of Set 10 | burica
# City not found. Skipping...
# Processing Record 18 of Set 10 | lindsay
# Processing Record 19 of Set 10 | ekhabi
# Processing Record 20 of Set 10 | sakakah
# Processing Record 21 of Set 10 | manado
# Processing Record 22 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 23 of Set 10 | nioro
# Processing Record 24 of Set 10 | guadalupe y calvo
# Processing Record 25 of Set 10 | sosnovo
# Processing Record 26 of Set 10 | tomatlan
# Processing Record 27 of Set 10 | tautira
# Processing Record 28 of Set 10 | ouesso
# Processing Record 29 of Set 10 | san lawrenz
# Processing Record 30 of Set 10 | buala
# Processing Record 31 of Set 10 | baherden
# Processing Record 32 of Set 10 | sao jose da coroa grande
# Processing Record 33 of Set 10 | nizwa
# Processing Record 34 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 35 of Set 10 | saint-georges
# Processing Record 36 of Set 10 | makakilo city
# Processing Record 37 of Set 10 | port hueneme
# Processing Record 38 of Set 10 | da nang
# Processing Record 39 of Set 10 | drayton valley
# Processing Record 40 of Set 10 | kristiansund
# Processing Record 41 of Set 10 | san quintin
# Processing Record 42 of Set 10 | bosaso
# Processing Record 43 of Set 10 | cidreira
# Processing Record 44 of Set 10 | fort nelson
# Processing Record 45 of Set 10 | listvyanka
# Processing Record 46 of Set 10 | northam
# Processing Record 47 of Set 10 | nagato
# Processing Record 48 of Set 10 | matara
# Processing Record 49 of Set 10 | kampot
# Processing Record 50 of Set 10 | columbus
# Processing Record 1 of Set 11 | mishelevka
# Processing Record 2 of Set 11 | quepos
# Processing Record 3 of Set 11 | inta
# Processing Record 4 of Set 11 | benguela
# Processing Record 5 of Set 11 | port shepstone
# Processing Record 6 of Set 11 | dekernes
# Processing Record 7 of Set 11 | pringsewu
# Processing Record 8 of Set 11 | ekangala
# Processing Record 9 of Set 11 | marzuq
# Processing Record 10 of Set 11 | phetchabun
# Processing Record 11 of Set 11 | turbat
# Processing Record 12 of Set 11 | kahului
# Processing Record 13 of Set 11 | warburton
# Processing Record 14 of Set 11 | pangnirtung
# Processing Record 15 of Set 11 | hauterive
# Processing Record 16 of Set 11 | odlabari
# Processing Record 17 of Set 11 | ambon
# Processing Record 18 of Set 11 | emmett
# Processing Record 19 of Set 11 | wenling
# Processing Record 20 of Set 11 | yate
# Processing Record 21 of Set 11 | rafsanjan
# Processing Record 22 of Set 11 | talnakh
# Processing Record 23 of Set 11 | gat
# Processing Record 24 of Set 11 | constitucion
# Processing Record 25 of Set 11 | gulf gate estates
# Processing Record 26 of Set 11 | coahuayana
# Processing Record 27 of Set 11 | lincoln
# Processing Record 28 of Set 11 | sarangani
# Processing Record 29 of Set 11 | kargil
# Processing Record 30 of Set 11 | juazeiro
# Processing Record 31 of Set 11 | idlib
# Processing Record 32 of Set 11 | hokitika
# Processing Record 33 of Set 11 | ganzhou
# Processing Record 34 of Set 11 | pochutla
# Processing Record 35 of Set 11 | dakar
# Processing Record 36 of Set 11 | tommot
# Processing Record 37 of Set 11 | balkhash
# Processing Record 38 of Set 11 | prosvet
# Processing Record 39 of Set 11 | dodoma
# Processing Record 40 of Set 11 | baykit
# Processing Record 41 of Set 11 | salinas
# Processing Record 42 of Set 11 | kangaba
# Processing Record 43 of Set 11 | mandurah
# Processing Record 44 of Set 11 | mackay
# Processing Record 45 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 11 | imbituba
# Processing Record 47 of Set 11 | opobo
# City not found. Skipping...
# Processing Record 48 of Set 11 | brandenburg
# Processing Record 49 of Set 11 | chadan
# Processing Record 50 of Set 11 | semnan
# Processing Record 1 of Set 12 | yumen
# Processing Record 2 of Set 12 | lubao
# Processing Record 3 of Set 12 | ipueiras
# Processing Record 4 of Set 12 | impfondo
# Processing Record 5 of Set 12 | vaitape
# Processing Record 6 of Set 12 | novobirilyussy
# Processing Record 7 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 8 of Set 12 | taldan
# Processing Record 9 of Set 12 | kadoma
# Processing Record 10 of Set 12 | cravinhos
# Processing Record 11 of Set 12 | margen
# Processing Record 12 of Set 12 | itaqui
# Processing Record 13 of Set 12 | abbeville
# Processing Record 14 of Set 12 | pemangkat
# Processing Record 15 of Set 12 | bomet
# Processing Record 16 of Set 12 | mount pleasant
# Processing Record 17 of Set 12 | bintulu
# Processing Record 18 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 19 of Set 12 | chambas
# Processing Record 20 of Set 12 | radnevo
# Processing Record 21 of Set 12 | shimoda
# Processing Record 22 of Set 12 | yuci
# Processing Record 23 of Set 12 | taksimo
# Processing Record 24 of Set 12 | qasigiannguit
# Processing Record 25 of Set 12 | batemans bay
# Processing Record 26 of Set 12 | aketi
# Processing Record 27 of Set 12 | havoysund
# Processing Record 28 of Set 12 | klyuchi
# Processing Record 29 of Set 12 | oklahoma city
# Processing Record 30 of Set 12 | nguru
# Processing Record 31 of Set 12 | pacific grove
# Processing Record 32 of Set 12 | grindavik
# Processing Record 33 of Set 12 | jumla
# Processing Record 34 of Set 12 | hammerfest
# Processing Record 35 of Set 12 | kalamazoo
# Processing Record 36 of Set 12 | ust-kuyga
# Processing Record 37 of Set 12 | urumqi
# Processing Record 38 of Set 12 | khasan
# Processing Record 39 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 12 | susaki
# Processing Record 41 of Set 12 | svrljig
# Processing Record 42 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 43 of Set 12 | prainha
# Processing Record 44 of Set 12 | malazgirt
# Processing Record 45 of Set 12 | mogochin
# City not found. Skipping...
# Processing Record 46 of Set 12 | luanda
# Processing Record 47 of Set 12 | sovetskoye
# Processing Record 48 of Set 12 | port-cartier
# Processing Record 49 of Set 12 | paamiut
# Processing Record 50 of Set 12 | sackville
# Processing Record 1 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 13 | kupang
# Processing Record 3 of Set 13 | kolondieba
# Processing Record 4 of Set 13 | bogale
# Processing Record 5 of Set 13 | panaba
# Processing Record 6 of Set 13 | reserva
# Processing Record 7 of Set 13 | kurchum
# Processing Record 8 of Set 13 | uthal
# Processing Record 9 of Set 13 | chapais
# Processing Record 10 of Set 13 | launceston
# Processing Record 11 of Set 13 | cabo san lucas
# Processing Record 12 of Set 13 | puerto baquerizo moreno
# Processing Record 13 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 13 | metro
# Processing Record 15 of Set 13 | kotido
# Processing Record 16 of Set 13 | dicabisagan
# Processing Record 17 of Set 13 | broken hill
# Processing Record 18 of Set 13 | dvurechensk
# Processing Record 19 of Set 13 | comodoro rivadavia
# Processing Record 20 of Set 13 | darab
# Processing Record 21 of Set 13 | nantucket
# Processing Record 22 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 23 of Set 13 | viedma
# Processing Record 24 of Set 13 | terre haute
# Processing Record 25 of Set 13 | vuktyl
# Processing Record 26 of Set 13 | suez
# Processing Record 27 of Set 13 | kulhudhuffushi
# Processing Record 28 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 29 of Set 13 | honiara
# Processing Record 30 of Set 13 | sungairaya
# Processing Record 31 of Set 13 | krasnoselkup
# Processing Record 32 of Set 13 | morden
# Processing Record 33 of Set 13 | cacheu
# Processing Record 34 of Set 13 | goroka
# Processing Record 35 of Set 13 | sinnamary
# Processing Record 36 of Set 13 | dingle
# Processing Record 37 of Set 13 | saint-joseph
# Processing Record 38 of Set 13 | lancut
# Processing Record 39 of Set 13 | leningradskiy
# Processing Record 40 of Set 13 | rabo de peixe
# Processing Record 41 of Set 13 | sal rei
# Processing Record 42 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 13 | birao
# Processing Record 44 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 45 of Set 13 | jesus maria
# Processing Record 46 of Set 13 | caidian
# Processing Record 47 of Set 13 | artsyz
# Processing Record 48 of Set 13 | solwezi
# Processing Record 49 of Set 13 | roald
# Processing Record 50 of Set 13 | kuruman
# Processing Record 1 of Set 14 | adana
# Processing Record 2 of Set 14 | tadine
# Processing Record 3 of Set 14 | sola
# Processing Record 4 of Set 14 | ilam
# Processing Record 5 of Set 14 | wewak
# Processing Record 6 of Set 14 | belaya gora
# Processing Record 7 of Set 14 | moindou
# Processing Record 8 of Set 14 | iracoubo
# Processing Record 9 of Set 14 | homer
# Processing Record 10 of Set 14 | naze
# Processing Record 11 of Set 14 | sao miguel do araguaia
# Processing Record 12 of Set 14 | kathu
# Processing Record 13 of Set 14 | abay
# Processing Record 14 of Set 14 | antalaha
# Processing Record 15 of Set 14 | the valley
# Processing Record 16 of Set 14 | tamworth
# Processing Record 17 of Set 14 | bandarban
# Processing Record 18 of Set 14 | zyryanka
# Processing Record 19 of Set 14 | bagdarin
# Processing Record 20 of Set 14 | hervey bay
# Processing Record 21 of Set 14 | sambava
# Processing Record 22 of Set 14 | carmen
# Processing Record 23 of Set 14 | negombo
# Processing Record 24 of Set 14 | letka
# Processing Record 25 of Set 14 | avera
# Processing Record 26 of Set 14 | panama city
# Processing Record 27 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 14 | hvolsvollur
# Processing Record 29 of Set 14 | pitimbu
# Processing Record 30 of Set 14 | tilichiki
# Processing Record 31 of Set 14 | salinopolis
# Processing Record 32 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 14 | skibbereen
# Processing Record 34 of Set 14 | beauly
# Processing Record 35 of Set 14 | port lincoln
# Processing Record 36 of Set 14 | monopoli
# Processing Record 37 of Set 14 | kapoeta
# Processing Record 38 of Set 14 | san rafael
# Processing Record 39 of Set 14 | veere
# Processing Record 40 of Set 14 | port-gentil
# Processing Record 41 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 14 | fairbanks
# Processing Record 43 of Set 14 | kattivakkam
# Processing Record 44 of Set 14 | murten
# Processing Record 45 of Set 14 | komsomolskiy
# Processing Record 46 of Set 14 | malakal
# Processing Record 47 of Set 14 | pozo colorado
# Processing Record 48 of Set 14 | falam
# Processing Record 49 of Set 14 | eyl
# Processing Record 50 of Set 14 | brae
# Processing Record 1 of Set 15 | springfield
# Processing Record 2 of Set 15 | coquimbo
# Processing Record 3 of Set 15 | iwanai
# Processing Record 4 of Set 15 | fukue
# Processing Record 5 of Set 15 | udachnyy
# Processing Record 6 of Set 15 | tarauaca
# Processing Record 7 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 15 | cacoal
# Processing Record 9 of Set 15 | bien hoa
# Processing Record 10 of Set 15 | murray bridge
# Processing Record 11 of Set 15 | carberry
# Processing Record 12 of Set 15 | boyolangu
# Processing Record 13 of Set 15 | sept-iles
# Processing Record 14 of Set 15 | hualmay
# Processing Record 15 of Set 15 | tacuarembo
# Processing Record 16 of Set 15 | maiduguri
# Processing Record 17 of Set 15 | warmbad
# Processing Record 18 of Set 15 | hibbing
# Processing Record 19 of Set 15 | gore
# Processing Record 20 of Set 15 | vadeni
# Processing Record 21 of Set 15 | batagay
# Processing Record 22 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 23 of Set 15 | lubumbashi
# Processing Record 24 of Set 15 | cap malheureux
# Processing Record 25 of Set 15 | pierre
# Processing Record 26 of Set 15 | omsukchan
# Processing Record 27 of Set 15 | kralendijk
# Processing Record 28 of Set 15 | paracuru
# Processing Record 29 of Set 15 | kieta
# Processing Record 30 of Set 15 | byron bay
# Processing Record 31 of Set 15 | jining
# Processing Record 32 of Set 15 | havelock
# Processing Record 33 of Set 15 | nanakuli
# Processing Record 34 of Set 15 | ahero
# Processing Record 35 of Set 15 | taree
# Processing Record 36 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 37 of Set 15 | talaya
# Processing Record 38 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 15 | tashara
# Processing Record 40 of Set 15 | roma
# Processing Record 41 of Set 15 | siaya
# Processing Record 42 of Set 15 | ende
# Processing Record 43 of Set 15 | zolotonosha
# Processing Record 44 of Set 15 | saint-denis
# Processing Record 45 of Set 15 | apac
# Processing Record 46 of Set 15 | reichenau
# Processing Record 47 of Set 15 | caimito
# Processing Record 48 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 49 of Set 15 | mwinilunga
# Processing Record 50 of Set 15 | morgan city
# Processing Record 1 of Set 16 | inverell
# Processing Record 2 of Set 16 | zaragoza
# Processing Record 3 of Set 16 | hofn
# Processing Record 4 of Set 16 | ugoofaaru
# Processing Record 5 of Set 16 | altay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 691

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    North Bend      US  43.4065 -124.2243     66.24        87         100
# 1       Rikitea      PF -23.1203 -134.9692     74.64        77         100
# 2        Avarua      CK -21.2078 -159.7750     71.65        68         100
# 3     Ivangorod      RU  59.3716   28.2162     64.54        83          42
# 4         Bluff      NZ -46.6000  168.3333     35.80        70          66
# 5    Bredasdorp      ZA -34.5322   20.0403     56.19        68          19
# 6  Punta Arenas      CL -53.1500  -70.9167     32.11        64          20
# 7        Albany      US  42.6001  -73.9662     76.95        49           1
# 8       Maumere      ID  -8.6199  122.2111     77.29        81          46
# 9        Barrow      US  71.2906 -156.7887     48.22        81           0
#
#    Wind Speed Current Description
# 0        8.05     overcast clouds
# 1       15.84          light rain
# 2        8.05     overcast clouds
# 3        2.42    scattered clouds
# 4        4.07       broken clouds
# 5        8.77          few clouds
# 6       11.50          few clouds
# 7        6.29           clear sky
# 8        3.85    scattered clouds
# 9       11.50           clear sky

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
